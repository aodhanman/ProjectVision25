# %% [markdown]
# <a href="https://colab.research.google.com/github/aodhanman/ProjectVision25/blob/main/practiceExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import os
import glob
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, precision_recall_fscore_support
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
from sklearn.metrics import confusion_matrix , ConfusionMatrixDisplay
from scikitplot.metrics import plot_roc

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# The action to 'open in Visual Studio' cannot be performed directly from Colab.

# %%
class CFG:
    EPOCHS= 50
    BATCH_SIZE= 64
    SEED= 42
    TF_SEED= 768
    HEIGHT= 224
    WIDTH= 224
    CHANNELS= 3
    IMAGE_SIZE=(224,224,3)

# %%
DATASET_PATH="../input/chest-xray-covid19-pneumonia/Data/"
TRAIN_PATH=  "../input/chest-xray-covid19-pneumonia/Data/train/"
TEST_PATH= "../input/chest-xray-covid19-pneumonia/Data/test/"

# %%
from google.colab import drive
drive.mount('https://drive.google.com/drive/folders/1zf2GTaSVoUynqm0p8_8zxNwk2l4IgVWf?usp=drive_link')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-779543746.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('https://drive.google.com/drive/folders/1zf2GTaSVoUynqm0p8_8zxNwk2l4IgVWf?usp=drive_link')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     198     normed = _os.path.normpath(mountpoint)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
